# %%
import pandas as pd

# %%
df = pd.read_csv('data/df.csv')
df
# Out:
#    proposal_panel_id  project_id proposal_status_abbreviation_description
# 0              P2019           1                                      AWD
# 1              P2019           2                                     DECL
# 2              P2019           3                                      AWD
# 3              P2019           4                                     DECL
# 4              P2019           5                                     PEND
# 5              P2018           6                                      AWD
# 6              P2018           7                                     DECL
# 7              P2018           8                                      WTH
# 8              P2018           9                                     PEND
# 9              P2018          10                                     DECL
# 10             P2018          11                                     DECL
# 11             P2018          12                                     DECL

# %%
df = df.groupby(['proposal_panel_id', 'proposal_status_abbreviation_description']).count()
df
# Out:
#                                                             project_id
# proposal_panel_id proposal_status_abbreviation_description
# P2018             AWD                                                1
#                   DECL                                               4
#                   PEND                                               1
#                   WTH                                                1
# P2019             AWD                                                2
#                   DECL                                               2
#                   PEND                                               1

# %%
df = df.pivot_table(values='project_id', index='proposal_panel_id',
               columns=['proposal_status_abbreviation_description'])
df
# Out:
# proposal_status_abbreviation_description  AWD  DECL  PEND  WTH
# proposal_panel_id
# P2018                                     1.0   4.0   1.0  1.0
# P2019                                     2.0   2.0   1.0  NaN

# %%
df['sucess_rate'] = df_wide['AWD']/(df_wide['AWD']+df_wide['DECL'])

# %%
df
# Out:
# proposal_status_abbreviation_description  AWD  DECL  PEND  WTH  sucess_rate
# proposal_panel_id
# P2018                                     1.0   4.0   1.0  1.0          0.2
# P2019                                     2.0   2.0   1.0  NaN          0.5
